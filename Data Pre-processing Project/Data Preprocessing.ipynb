# %% [markdown]
# Importing Pythons Libraries for Data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# Importing CSV Data

# %%
pd.read_csv(r"C:\Users\abdul\Desktop\Ecommerce_Consumer_Behavior_Analysis_Data.csv")
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
df = pd.read_csv(r"C:\Users\abdul\Desktop\Ecommerce_Consumer_Behavior_Analysis_Data.csv")

# %% [markdown]
# Checking Data Quality

# %%
df.dtypes
# Out:
# Customer_ID                               object
# Age                                        int64
# Gender                                    object
# Income_Level                              object
# Marital_Status                            object
# Education_Level                           object
# Occupation                                object
# Location                                  object
# Purchase_Category                         object
# Purchase_Amount                           object
# Frequency_of_Purchase                      int64
# Purchase_Channel                          object
# Brand_Loyalty                              int64
# Product_Rating                             int64
# Time_Spent_on_Product_Research(hours)    float64
# Social_Media_Influence                    object
# Discount_Sensitivity                      object
# Return_Rate                                int64
# Customer_Satisfaction                      int64
# ...

# %% [markdown]
# Replacing special characters and Data types

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].str.replace('$','')

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].astype(float)

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category  Purchase_Amount  ...  \
# ...

# %% [markdown]
# Looking All Columns

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category  Purchase_Amount  \
# ...

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status',
#        'Education_Level', 'Occupation', 'Location', 'Purchase_Category',
#        'Purchase_Amount', 'Frequency_of_Purchase', 'Purchase_Channel',
#        'Brand_Loyalty', 'Product_Rating',
#        'Time_Spent_on_Product_Research(hours)', 'Social_Media_Influence',
#        'Discount_Sensitivity', 'Return_Rate', 'Customer_Satisfaction',
#        'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
#        'Time_of_Purchase', 'Discount_Used', 'Customer_Loyalty_Program_Member',
#        'Purchase_Intent', 'Shipping_Preference', 'Time_to_Decision'],
#       dtype='object')

# %%
df[['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status',
       'Education_Level', 'Occupation', #'Location', 
        'Purchase_Category',
       'Purchase_Amount', 'Frequency_of_Purchase', #'Purchase_Channel',
       #'Brand_Loyalty', 'Product_Rating',
       #'Time_Spent_on_Product_Research(hours)', 
        #'Social_Media_Influence',
      # 'Discount_Sensitivity', 'Return_Rate', 'Customer_Satisfaction',
      # 'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
       'Time_of_Purchase', #'Discount_Used', #'Customer_Loyalty_Program_Member',
      # 'Purchase_Intent', 'Shipping_Preference', 'Time_to_Decision'
    ]]
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %% [markdown]
# Selecting Only Useful Columns

# %%
df = df[['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status',
       'Education_Level', 'Occupation', #'Location', 
        'Purchase_Category',
       'Purchase_Amount', 'Frequency_of_Purchase', #'Purchase_Channel',
       #'Brand_Loyalty', 'Product_Rating',
       #'Time_Spent_on_Product_Research(hours)', 
        #'Social_Media_Influence',
      # 'Discount_Sensitivity', 'Return_Rate', 'Customer_Satisfaction',
      # 'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
       'Time_of_Purchase', #'Discount_Used', #'Customer_Loyalty_Program_Member',
      # 'Purchase_Intent', 'Shipping_Preference', 'Time_to_Decision'
    ]]

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %% [markdown]
# Checking any Nulls Vales and droplicates Values

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Gender                   0
# Income_Level             0
# Marital_Status           0
# Education_Level          0
# Occupation               0
# Purchase_Category        0
# Purchase_Amount          0
# Frequency_of_Purchase    0
# Time_of_Purchase         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Fixing Names of specfic Columns

# %%
df['Purchase_Category'].unique()
# Out:
# array(['Gardening & Outdoors', 'Food & Beverages', 'Office Supplies',
#        'Home Appliances', 'Furniture', 'Books', 'Sports & Outdoors',
#        'Mobile Accessories', 'Luxury Goods', 'Animal Feed', 'Health Care',
#        'Hotels', 'Packages)', 'Electronics', 'Software & Apps',
#        'Baby Products', 'Toys & Games', 'Arts & Crafts',
#        'Health Supplements', 'Groceries', 'Clothing',
#        'Beauty & Personal Care', 'Travel & Leisure (Flights',
#        'Jewelry & Accessories'], dtype=object)

# %%
df['Purchase_Category'] = df['Purchase_Category'].str.replace('Packages)','Packages')
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\2980836348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Purchase_Category'] = df['Purchase_Category'].str.replace('Packages)','Packages')

# %%
df['Purchase_Category'].unique()
# Out:
# array(['Gardening & Outdoors', 'Food & Beverages', 'Office Supplies',
#        'Home Appliances', 'Furniture', 'Books', 'Sports & Outdoors',
#        'Mobile Accessories', 'Luxury Goods', 'Animal Feed', 'Health Care',
#        'Hotels', 'Packages', 'Electronics', 'Software & Apps',
#        'Baby Products', 'Toys & Games', 'Arts & Crafts',
#        'Health Supplements', 'Groceries', 'Clothing',
#        'Beauty & Personal Care', 'Travel & Leisure (Flights',
#        'Jewelry & Accessories'], dtype=object)

# %%
df['Purchase_Category'] = df['Purchase_Category'].str.replace('Travel & Leisure (Flights','Travel & Leisure Flights')
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\340980365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Purchase_Category'] = df['Purchase_Category'].str.replace('Travel & Leisure (Flights','Travel & Leisure Flights')

# %% [markdown]
# Checking Data Types of Columns

# %%
df.dtypes
# Out:
# Customer_ID               object
# Age                        int64
# Gender                    object
# Income_Level              object
# Marital_Status            object
# Education_Level           object
# Occupation                object
# Purchase_Category         object
# Purchase_Amount          float64
# Frequency_of_Purchase      int64
# Time_of_Purchase          object
# dtype: object

# %% [markdown]
# Changing Data types of Date Time

# %%
pd.to_datetime(df['Time_of_Purchase'])
# Out:
# 0     2024-03-01
# 1     2024-04-16
# 2     2024-03-15
# 3     2024-10-04
# 4     2024-01-30
#          ...
# 995   2024-07-07
# 996   2024-03-28
# 997   2024-03-11
# 998   2024-03-30
# 999   2024-12-08
# Name: Time_of_Purchase, Length: 1000, dtype: datetime64[ns]

# %%
df['Time_of_Purchase'] = pd.to_datetime(df['Time_of_Purchase'])
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\960662495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_of_Purchase'] = pd.to_datetime(df['Time_of_Purchase'])

# %%
df.dtypes
# Out:
# Customer_ID                      object
# Age                               int64
# Gender                           object
# Income_Level                     object
# Marital_Status                   object
# Education_Level                  object
# Occupation                       object
# Purchase_Category                object
# Purchase_Amount                 float64
# Frequency_of_Purchase             int64
# Time_of_Purchase         datetime64[ns]
# dtype: object

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %% [markdown]
# Rounding Off specfic values of Columns Purchase_Amount then changing Data type from float to int

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].round(0)
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\938680708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Purchase_Amount'] = df['Purchase_Amount'].round(0)

# %%
df['Purchase_Amount'].astype(int)
# Out:
# 0      334
# 1      222
# 2      426
# 3      101
# 4      212
#       ...
# 995    464
# 996     70
# 997    453
# 998    106
# 999    378
# Name: Purchase_Amount, Length: 1000, dtype: int64

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].astype(int)
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\1310936565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Purchase_Amount'] = df['Purchase_Amount'].astype(int)

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %% [markdown]
# Extracting Months and Year from column Time_of_Purchase and making new columns for them

# %%
df['Month'] = df['Time_of_Purchase'].dt.strftime('%B')
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\875660648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Time_of_Purchase'].dt.strftime('%B')

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %%
df['Year'] = df['Time_of_Purchase'].dt.strftime('%Y')
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\1497365667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Time_of_Purchase'].dt.strftime('%Y')

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Purchase_Category  Purchase_Amount  Frequency_of_Purchase  \
# ...

# %% [markdown]
# Last time checking Data types of columns

# %%
df.dtypes
# Out:
# Customer_ID              object
# Age                       int64
# Gender                   object
# Income_Level             object
# Marital_Status           object
# Education_Level          object
# Occupation               object
# Purchase_Category        object
# Purchase_Amount           int64
# Frequency_of_Purchase     int64
# Time_of_Purchase         object
# Month                    object
# Year                     object
# dtype: object

# %% [markdown]
# Changing the new columns data types

# %%
df['Year']=df['Year'].astype(int)
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\1925074224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=df['Year'].astype(int)

# %%
df.dtypes
# Out:
# Customer_ID              object
# Age                       int64
# Gender                   object
# Income_Level             object
# Marital_Status           object
# Education_Level          object
# Occupation               object
# Purchase_Category        object
# Purchase_Amount           int64
# Frequency_of_Purchase     int64
# Time_of_Purchase         object
# Month                    object
# Year                      int64
# dtype: object

# %%
df['Time_of_Purchase'] = pd.to_datetime(df['Time_of_Purchase'])
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3200\960662495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_of_Purchase'] = pd.to_datetime(df['Time_of_Purchase'])

# %%
df.dtypes
# Out:
# Customer_ID                      object
# Age                               int64
# Gender                           object
# Income_Level                     object
# Marital_Status                   object
# Education_Level                  object
# Occupation                       object
# Purchase_Category                object
# Purchase_Amount                   int64
# Frequency_of_Purchase             int64
# Time_of_Purchase         datetime64[ns]
# Month                            object
# Year                              int64
# dtype: object

# %% [markdown]
# Saving it in Excel File

# %%
df.to_excel('Final.xlsx',index=False)
