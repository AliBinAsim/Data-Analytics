# %%
import pandas as pd

# %%
df = pd.read_csv(r"K:\GTA\global_freelancers_raw.csv")

# %% [markdown]
# Importing Pandas for Data Cleaning and Reading CSV File ( Uncleaned Data )

# %%
df
# Out:
#     freelancer_ID             name  gender   age    country  language  \
# 0        FL250001  Ms. Nicole Kidd       f  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  FEMALE  52.0  Australia   English
# 2        FL250003      Juan Nelson    male  53.0    Germany    German
# 3        FL250004   Amanda Spencer       F  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris       f  26.0    Germany    German
# 997      FL250998    Kathy Watkins  female  37.0      Japan  Japanese
# 998      FL250999      John Obrien       m  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               primary_skill  years_of_experience hourly_rate (USD)  rating  \
# ...

# %% [markdown]
# Checking data type of columns and and their names

# %%
df.dtypes
# Out:
# freelancer_ID           object
# name                    object
# gender                  object
# age                    float64
# country                 object
# language                object
# primary_skill           object
# years_of_experience    float64
# hourly_rate (USD)       object
# rating                 float64
# is_active               object
# client_satisfaction     object
# dtype: object

# %%
df.columns
# Out:
# Index(['freelancer_ID', 'name', 'gender', 'age', 'country', 'language',
#        'primary_skill', 'years_of_experience', 'hourly_rate (USD)', 'rating',
#        'is_active', 'client_satisfaction'],
#       dtype='object')

# %% [markdown]
# Renameing their Columns to more standard name

# %%
df = df[['freelancer_ID', 'name', 'gender', 'age', 'country', 'language',
       'primary_skill', 'years_of_experience', 'hourly_rate (USD)', 'rating',
       'client_satisfaction']]

# %%
df
# Out:
#     freelancer_ID             name  gender   age    country  language  \
# 0        FL250001  Ms. Nicole Kidd       f  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  FEMALE  52.0  Australia   English
# 2        FL250003      Juan Nelson    male  53.0    Germany    German
# 3        FL250004   Amanda Spencer       F  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris       f  26.0    Germany    German
# 997      FL250998    Kathy Watkins  female  37.0      Japan  Japanese
# 998      FL250999      John Obrien       m  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               primary_skill  years_of_experience hourly_rate (USD)  rating  \
# ...

# %%
df = df.rename(columns={'name':'Name','gender':'Gender','age':'Age','country':'Country','language':'Language','primary_skill':'Primary_Skill', 'years_of_experience': 'Years_of_Experience','hourly_rate (USD)':'Hourly_Rate','client_satisfaction':'Client_Satisfaction','rating':'Rating'})

# %%
df
# Out:
#     freelancer_ID             Name  Gender   Age    Country  Language  \
# 0        FL250001  Ms. Nicole Kidd       f  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  FEMALE  52.0  Australia   English
# 2        FL250003      Juan Nelson    male  53.0    Germany    German
# 3        FL250004   Amanda Spencer       F  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris       f  26.0    Germany    German
# 997      FL250998    Kathy Watkins  female  37.0      Japan  Japanese
# 998      FL250999      John Obrien       m  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate  Rating  \
# ...

# %% [markdown]
# Renames Gender columns to more formal names

# %%
df['Gender'] = df['Gender'].str.lower().replace({
    'f': 'Female',
    'female': 'Female',
    'm': 'Male',
    'male': 'Male'
})

# %%
df
# Out:
#     freelancer_ID             Name  Gender   Age    Country  Language  \
# 0        FL250001  Ms. Nicole Kidd  Female  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  Female  52.0  Australia   English
# 2        FL250003      Juan Nelson    Male  53.0    Germany    German
# 3        FL250004   Amanda Spencer  Female  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  Female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris  Female  26.0    Germany    German
# 997      FL250998    Kathy Watkins  Female  37.0      Japan  Japanese
# 998      FL250999      John Obrien    Male  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate  Rating  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# Remove NA values

# %%
df.dropna()
# Out:
#     freelancer_ID             Name  Gender   Age       Country    Language  \
# 1        FL250002   Vanessa Garcia  Female  52.0     Australia     English
# 2        FL250003      Juan Nelson    Male  53.0       Germany      German
# 3        FL250004   Amanda Spencer  Female  38.0     Australia     English
# 4        FL250005  Lynn Curtis DDS  Female  53.0       Germany      German
# 6        FL250007       Eric Myers    Male  52.0     Indonesia  Indonesian
# ..            ...              ...     ...   ...           ...         ...
# 994      FL250995  Jennifer Hinton  Female  34.0  South Africa   Afrikaans
# 995      FL250996    Albert Wilcox    Male  56.0        Turkey     Turkish
# 996      FL250997    Cheryl Norris  Female  26.0       Germany      German
# 998      FL250999      John Obrien    Male  46.0        Russia     Russian
# 999      FL251000       Dawn Green  Female  36.0        Mexico     Spanish
#
# ...

# %%
df.rename(columns={'Hourly_Rate':'Hourly_Rate_in_USD'})
# Out:
#     freelancer_ID             Name  Gender   Age    Country  Language  \
# 0        FL250001  Ms. Nicole Kidd  Female  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  Female  52.0  Australia   English
# 2        FL250003      Juan Nelson    Male  53.0    Germany    German
# 3        FL250004   Amanda Spencer  Female  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  Female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris  Female  26.0    Germany    German
# 997      FL250998    Kathy Watkins  Female  37.0      Japan  Japanese
# 998      FL250999      John Obrien    Male  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate_in_USD  Rating  \
# ...

# %%
df['Hourly_Rate'].unique()
# Out:
# array(['100', 'USD 100', '50', '$40', '30', '$30', 'USD 75', 'USD 40',
#        nan, '$50', '40', '75', 'USD 50', 'USD 30', '$20', '20', '$75',
#        '$100', 'USD 20'], dtype=object)

# %% [markdown]
# Fixing Columns data of Hourly_Rate

# %%
df['Hourly_Rate'] = df['Hourly_Rate'].str.replace('USD','')
df['Hourly_Rate'] = df['Hourly_Rate'].str.replace('$','')

# %%
df
# Out:
#     freelancer_ID             Name  Gender   Age    Country  Language  \
# 0        FL250001  Ms. Nicole Kidd  Female  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  Female  52.0  Australia   English
# 2        FL250003      Juan Nelson    Male  53.0    Germany    German
# 3        FL250004   Amanda Spencer  Female  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  Female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris  Female  26.0    Germany    German
# 997      FL250998    Kathy Watkins  Female  37.0      Japan  Japanese
# 998      FL250999      John Obrien    Male  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate  Rating  \
# ...

# %%
df['Rating'] = df['Rating'].fillna('Unknown')

# %%
df.drop_duplicates()
# Out:
#     freelancer_ID             Name  Gender   Age    Country  Language  \
# 0        FL250001  Ms. Nicole Kidd  Female  52.0      Italy   Italian
# 1        FL250002   Vanessa Garcia  Female  52.0  Australia   English
# 2        FL250003      Juan Nelson    Male  53.0    Germany    German
# 3        FL250004   Amanda Spencer  Female  38.0  Australia   English
# 4        FL250005  Lynn Curtis DDS  Female  53.0    Germany    German
# ..            ...              ...     ...   ...        ...       ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey   Turkish
# 996      FL250997    Cheryl Norris  Female  26.0    Germany    German
# 997      FL250998    Kathy Watkins  Female  37.0      Japan  Japanese
# 998      FL250999      John Obrien    Male  46.0     Russia   Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico   Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate   Rating  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#     freelancer_ID             Name  Gender   Age    Country    Language  \
# 1        FL250002   Vanessa Garcia  Female  52.0  Australia     English
# 2        FL250003      Juan Nelson    Male  53.0    Germany      German
# 3        FL250004   Amanda Spencer  Female  38.0  Australia     English
# 4        FL250005  Lynn Curtis DDS  Female  53.0    Germany      German
# 6        FL250007       Eric Myers    Male  52.0  Indonesia  Indonesian
# ..            ...              ...     ...   ...        ...         ...
# 995      FL250996    Albert Wilcox    Male  56.0     Turkey     Turkish
# 996      FL250997    Cheryl Norris  Female  26.0    Germany      German
# 997      FL250998    Kathy Watkins  Female  37.0      Japan    Japanese
# 998      FL250999      John Obrien    Male  46.0     Russia     Russian
# 999      FL251000       Dawn Green  Female  36.0     Mexico     Spanish
#
#               Primary_Skill  Years_of_Experience Hourly_Rate   Rating  \
# ...

# %% [markdown]
# No Duplicates Found and saving the file

# %%
df.to_csv("Cleaned_Data_final_Global_Freelancers_Raw.csv",index=False)
